# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import t

# %%
# Importing required libraries for visualization and random number generation
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import t

# Generate 100 samples from a Gaussian (Normal) distribution with mean 0 and standard deviation 2
X_normal = np.random.normal(0, 2, 100)

# Generate 100 samples from a Uniform distribution between 0 and 2
X_uniform = np.random.uniform(0, 2, 100)

# Generate 100 samples from a Student's t-distribution with location 0, scale 2, and 1.5 degrees of freedom
df = 1.5  # degrees of freedom
loc = 0  # location
scale = 2  # scale
X_t = t.rvs(df, loc, scale, size=100)

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot Gaussian distribution
axs[0].hist(X_normal, bins=20, color='blue', edgecolor='black', alpha=0.7)
axs[0].set_title('Gaussian Distribution')
axs[0].set_xlabel('x')
axs[0].set_ylabel('Frequency')

# Plot Uniform distribution
axs[1].hist(X_uniform, bins=20, color='green', edgecolor='black', alpha=0.7)
axs[1].set_title('Uniform Distribution')
axs[1].set_xlabel('x')
axs[1].set_ylabel('Frequency')

# Plot Student's t-distribution
axs[2].hist(X_t, bins=20, color='red', edgecolor='black', alpha=0.7)
axs[2].set_title("Student's t-Distribution")
axs[2].set_xlabel('x')
axs[2].set_ylabel('Frequency')

# Show plots
plt.show()

# %% [markdown]
# Gaussian Distribution: The first plot shows 100 samples from a Gaussian distribution with mean 0 and standard deviation 2. You can see the classic "bell curve" shape.

# %%
# Generate 100 samples from a Gaussian (Normal) distribution with mean 0 and standard deviation 2
X_normal = np.random.normal(0, 2, (100, 1))

# Create subplots
fig, axs = plt.subplots(1, 1, figsize=(18, 6))

# Plot Gaussian distribution
plt.hist(X_normal, bins=20, color='blue', edgecolor='black', alpha=0.7)
plt.title('Gaussian Distribution')  # Updated this line
plt.xlabel('x')  # Updated this line
plt.ylabel('Frequency')  # Updated this line

# Show plots
plt.show()

# %% [markdown]
# Uniform Distribution: The second plot shows 100 samples from a uniform distribution between 0 and 2. The frequency of each bin should be roughly equal, given that the distribution is uniform.

# %%
X_uniform = np.random.uniform(0, 2, (100, 1))

# Plot Uniform distribution
plt.hist(X_uniform, bins=20, color='green', edgecolor='black', alpha=0.7)
plt.title('Uniform Distribution')
plt.xlabel('x')
plt.ylabel('Frequency')

# Show plots
plt.show()

# %% [markdown]
# Student's t-Distribution: The third plot shows 100 samples from a Student's t-distribution with 1.5 degrees of freedom, a location of 0, and a scale of 2. The distribution is somewhat similar to the Gaussian distribution but has heavier tails.

# %%
df = 1.5  # degrees of freedom
loc = 0  # location
scale = 2  # scale

X_t = t.rvs(df, loc, scale, size=(100, 1))

# Plot Student's t-distribution
plt.hist(X_t, bins=20, color='red', edgecolor='black', alpha=0.7)
plt.title("Student's t-Distribution")
plt.xlabel('x')
plt.ylabel('Frequency')

# Show plots
plt.show()
